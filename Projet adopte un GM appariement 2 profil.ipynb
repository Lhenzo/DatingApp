# %%
nom_fichier = "C:\\Users\\Lorenzo\\01Informatique\\01Informatique upmc\\Exercices\Profil Database" #Chemin du fichier

profil_r=input('Personne 1 : ')
profil_r2=input('Personne 2 :  ')

print('Commençons l\'étude de compatibilité')
# Out:
# Personne 1 : lolodu13
# Personne 2 :  constdu97
# Commençons l'étude de compatibilité

# %%
#Genre recherché compatible

affichage = open(nom_fichier,"r", encoding = 'utf-8') 

#Pour chaque ligne du contenu lu dans le fichier des profils, on vient chercher les profils à comparer
for ligne in affichage:     
    if profil_r in ligne:
        ligne = ligne.rstrip()

#Création d'une liste séparant les variables
        liste_affichage = ligne.split(',')
        genre = liste_affichage[2]
        genre_r = liste_affichage[7]
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        genre2 = liste_affichage[2]
        genre_r2 = liste_affichage[7]

affichage.close()        

if genre_r != genre2:
    print('{} ne recherche pas le genre de {}'.format(profil_r, profil_r2))
elif genre_r2 != genre:
    print('{} ne recherche pas le genre de {}'.format(profil_r2, profil_r))
else:
    print('Vous vous recherchez mutuellement')
# Out:
# Vous vous recherchez mutuellement

# %%
#Détermination du chemin de vie

distance_cumulée = 0

affichage = open(nom_fichier,"r", encoding = 'utf-8') 

#Pour chaque ligne du contenu lu dans le fichier des profils, on vient chercher les profils à comparer
for ligne in affichage:     
    if profil_r in ligne:
        ligne = ligne.rstrip()

#Création d'une liste séparant les variables
        liste_affichage = ligne.split(',')
        
#On vient prendre ce qui nous intéresse, ici la date de naissance, en position 1 de la liste créée
        affichage_naissance = liste_affichage[1]
        date_naissance = affichage_naissance.split('/')
        jour=int(date_naissance[0])
        mois=int(date_naissance[1])
        annee=int(date_naissance[2])
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        affichage_naissance2 = liste_affichage[1]
        date_naissance2 = affichage_naissance2.split('/')
        jour2=int(date_naissance2[0])
        mois2=int(date_naissance2[1])
        annee2=int(date_naissance2[2])

#Ne jamais oublier de fermer le fichier
affichage.close()

chemin_de_vie=jour+mois+annee
chemin_de_vie2=jour2+mois2+annee2


while chemin_de_vie > 9:
    chemin_de_vie = sum(map(int,str(chemin_de_vie)))
    
while chemin_de_vie2 > 9:
    chemin_de_vie2 = sum(map(int,str(chemin_de_vie2)))

    
#Valeur absolue pour ne prendre que la distance et non les signes.
distance = abs(chemin_de_vie-chemin_de_vie2)
distance_cumulée = distance_cumulée + distance
print("\nChemin de vie de {} : {}\nChemin de vie de {} : {}\nDistance : {}\nDistance cumulée : {}".format(profil_r, chemin_de_vie, profil_r2, chemin_de_vie2, distance, distance_cumulée))
# Out:
# Chemin de vie de lolodu13 : 2
# Chemin de vie de constdu97 : 4
# Distance : 2
# Distance cumulée : 2

# %%
#Compatibilité astro


#Création de la matrice de données

ASTRO = [[1 for j in range(1,14)] for i in range(1,14)]
 
ASTRO[1][1]=50
ASTRO[1][2]=70
ASTRO[1][3]=50
ASTRO[1][4]=50
ASTRO[1][5]=60
ASTRO[1][6]=50
ASTRO[1][7]=70
ASTRO[1][8]=60
ASTRO[1][9]=70
ASTRO[1][10]=45
ASTRO[1][11]=90
ASTRO[1][12]=45

ASTRO[2][1]=85
ASTRO[2][2]=90
ASTRO[2][3]=70
ASTRO[2][4]=80
ASTRO[2][5]=55
ASTRO[2][6]=80
ASTRO[2][7]=70
ASTRO[2][8]=90
ASTRO[2][9]=80
ASTRO[2][10]=80
ASTRO[2][11]=60
ASTRO[2][12]=90


ASTRO[3][1]=50
ASTRO[3][2]=60
ASTRO[3][3]=75
ASTRO[3][4]=60
ASTRO[3][5]=50
ASTRO[3][6]=60
ASTRO[3][7]=70
ASTRO[3][8]=60
ASTRO[3][9]=70
ASTRO[3][10]=90
ASTRO[3][11]=90
ASTRO[3][12]=40

ASTRO[4][1]=50
ASTRO[4][2]=95
ASTRO[4][3]=65
ASTRO[4][4]=55
ASTRO[4][5]=95
ASTRO[4][6]=90
ASTRO[4][7]=75
ASTRO[4][8]=80
ASTRO[4][9]=55
ASTRO[4][10]=55
ASTRO[4][11]=70
ASTRO[4][12]=70

ASTRO[5][1]=50
ASTRO[5][2]=55
ASTRO[5][3]=45
ASTRO[5][4]=95
ASTRO[5][5]=45
ASTRO[5][6]=70
ASTRO[5][7]=70
ASTRO[5][8]=75
ASTRO[5][9]=90
ASTRO[5][10]=80
ASTRO[5][11]=70
ASTRO[5][12]=45

ASTRO[6][1]=40
ASTRO[6][2]=55
ASTRO[6][3]=55
ASTRO[6][4]=90
ASTRO[6][5]=75
ASTRO[6][6]=60
ASTRO[6][7]=60
ASTRO[6][8]=80
ASTRO[6][9]=80
ASTRO[6][10]=60
ASTRO[6][11]=40
ASTRO[6][12]=55

ASTRO[7][1]=60
ASTRO[7][2]=55
ASTRO[7][3]=65
ASTRO[7][4]=75
ASTRO[7][5]=90
ASTRO[7][6]=60
ASTRO[7][7]=70
ASTRO[7][8]=65
ASTRO[7][9]=90
ASTRO[7][10]=50
ASTRO[7][11]=90
ASTRO[7][12]=55

ASTRO[8][1]=55
ASTRO[8][2]=85
ASTRO[8][3]=60
ASTRO[8][4]=70
ASTRO[8][5]=90
ASTRO[8][6]=70
ASTRO[8][7]=55
ASTRO[8][8]=40
ASTRO[8][9]=95
ASTRO[8][10]=55
ASTRO[8][11]=50
ASTRO[8][12]=90

ASTRO[9][1]=60
ASTRO[9][2]=50
ASTRO[9][3]=70
ASTRO[9][4]=60
ASTRO[9][5]=90
ASTRO[9][6]=55
ASTRO[9][7]=85
ASTRO[9][8]=95
ASTRO[9][9]=90
ASTRO[9][10]=65
ASTRO[9][11]=90
ASTRO[9][12]=90

ASTRO[10][1]=60
ASTRO[10][2]=95
ASTRO[10][3]=70
ASTRO[10][4]=65
ASTRO[10][5]=90
ASTRO[10][6]=50
ASTRO[10][7]=45
ASTRO[10][8]=65
ASTRO[10][9]=40
ASTRO[10][10]=85
ASTRO[10][11]=80
ASTRO[10][12]=90

ASTRO[11][1]=70
ASTRO[11][2]=55
ASTRO[11][3]=80
ASTRO[11][4]=60
ASTRO[11][5]=80
ASTRO[11][6]=40
ASTRO[11][7]=90
ASTRO[11][8]=50
ASTRO[11][9]=75
ASTRO[11][10]=70
ASTRO[11][11]=75
ASTRO[11][12]=70

ASTRO[12][1]=45
ASTRO[12][2]=90
ASTRO[12][3]=40
ASTRO[12][4]=70
ASTRO[12][5]=50
ASTRO[12][6]=65
ASTRO[12][7]=70
ASTRO[12][8]=65
ASTRO[12][9]=80
ASTRO[12][10]=70
ASTRO[12][11]=45
ASTRO[12][12]=75


#Même processus que décrit au dessus
affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        signe_compare = int(liste_affichage[3])
        genre_compare = int(liste_affichage[2])
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        signe_compare2 = int(liste_affichage[3])
        genre_compare2 = int(liste_affichage[2])
            
affichage.close()
 
#Le résultat est de la forme 100 - {..} car on veut obtenir une distance astrologique    
if genre_compare==1:
    résultat = 100-(ASTRO[signe_compare2][signe_compare])
    
else:
    résultat = 100-(ASTRO[signe_compare][signe_compare2])

#On cumule les distances
distance_cumulée = distance_cumulée + résultat
print('La distance astrologique entre ces deux personnes est de : {}\nDistance cumulée : {}'.format(résultat, distance_cumulée))
# Out:
# La distance astrologique entre ces deux personnes est de : 35
# Distance cumulée : 37

# %%
#Différence d'âge

#Même exemple que pour la saisie d'un profil concernant l'âge ici
import datetime
today=datetime.date.today()
liste_today=str(today).split("-")
liste_today.reverse()
liste_today

valeur = 1

age_recherché = {'Entre 18 et 22ans exclu' : 1, 'Entre 22 et 26ans exclu' : 2, 'Entre 26 et 30ans exclu' : 3, 'Entre 30 et 34ans exclu' : 4, 'Entre 34 et 38ans exclu' : 5, '38 ans ou plus' : 6, 'Peu importe..' : 7}

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        affichage_age = liste_affichage[1]
        affichage_age_r = int(liste_affichage[8])
        age_liste=affichage_age.split("/")
        age=int(liste_today[2])-int(age_liste[2])
        
        if (int(liste_today[1])-int(age_liste[1]))<0:
            age=age-1

        if (int(liste_today[1])-int(age_liste[1]))==0:
            if (int(liste_today[0])-int(age_liste[0]))<0:
                age=age-1
        
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        affichage_age2 = liste_affichage[1]
        affichage_age_r2 = int(liste_affichage[8])
        age_liste2=affichage_age.split("/")
        age2=int(liste_today[2])-int(age_liste2[2])

        if (int(liste_today[1])-int(age_liste2[1]))<0:
            age2=age-1

        if (int(liste_today[1])-int(age_liste2[1]))==0:
            if (int(liste_today[0])-int(age_liste2[0]))<0:
                age2=age-1
        
affichage.close()
distance = []

if affichage_age_r2 == 1:
    liste_age = [18, 19, 20, 21]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1] #distance moyenne ne sachant pas rééllement l'âge en question
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 2:
    liste_age = [22, 23, 24, 25]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 3:
    liste_age = [26, 27, 28, 29]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 4:
    liste_age = [30, 31, 32, 33]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 5:
    liste_age = [34, 35, 36, 37]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 6:
    liste_age = [38]
    for elem in liste_age:
        distance.append(abs(age-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le premier utilisateur et le second rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r2 == 7:
    print('On ne peut pas évaluer la distance')
    
#comparaison inverse

if affichage_age_r == 1:
    liste_age = [18, 19, 20, 21]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 2:
    liste_age = [22, 23, 24, 25]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 3:
    liste_age = [26, 27, 28, 29]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 4:
    liste_age = [30, 31, 32, 33]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 5:
    liste_age = [34, 35, 36, 37]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 6:
    liste_age = [38]
    for elem in liste_age:
        distance.append(abs(age2-elem))
    distance_cumulée = distance_cumulée + distance[1]
    print('La distance entre le deuxième utilisateur et le premier rentré est de {}, {}, {} ou {}\nDistance cumulée : {}'.format(distance[0], distance[1], distance[2], distance[3], distance_cumulée))

if affichage_age_r == 7:
    print('On ne peut pas évaluer la distance')
#print(age, age2)
#changer les phrases
# Out:
# La distance entre le premier utilisateur et le second rentré est de 1, 2, 3 ou 4
# Distance cumulée : 39
# La distance entre le deuxième utilisateur et le premier rentré est de 1, 2, 3 ou 4
# Distance cumulée : 41

# %%
#Distance cheveux

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        cheveux = int(liste_affichage[5])
        cheveux_r = int(liste_affichage[10])
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        cheveux2 = int(liste_affichage[5])
        cheveux_r2 = int(liste_affichage[10])
        
affichage.close()

distance = cheveux_r-cheveux2
distance2 = cheveux_r2-cheveux
distance_tot = abs(distance + distance2)
distance_cumulée = distance_cumulée + distance_tot
print('Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : {}\nDistance cumulée : {} '.format(distance_tot, distance_cumulée))
# Out:
# Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : 1
# Distance cumulée : 42

# %%
#Distance yeux

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        yeux = int(liste_affichage[6])
        yeux_r = int(liste_affichage[11])
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        yeux2 = int(liste_affichage[6])
        yeux_r2 = int(liste_affichage[11])
        
affichage.close()

distance = yeux_r-yeux2
distance2 = yeux_r2-yeux
distance_tot = abs(distance + distance2)
distance_cumulée = distance_cumulée + distance_tot
print('Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : {}\nDistance cumulée : {} '.format(distance_tot, distance_cumulée))
# Out:
# Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : 1
# Distance cumulée : 43

# %%
#Distance taille

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        taille = int(liste_affichage[4])
        taille_r = int(liste_affichage[9])
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        taille2 = int(liste_affichage[4])
        taille_r2 = int(liste_affichage[9])
        
affichage.close()

distance = taille_r-taille2
distance2 = taille_r2-taille
distance_tot = abs(distance + distance2)
distance_cumulée = distance_cumulée + distance_tot
print('Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : {}\nDistance cumulée : {} '.format(distance_tot, distance_cumulée))
# Out:
# Distance totale entre la couleur de cheveux recherché et la couleur de cheveux de chaque personnes : 0
# Distance cumulée : 57

# %%
#Distance questions

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        question1 = int(liste_affichage[12])
        question2 = int(liste_affichage[13])
        question3 = int(liste_affichage[14])
        question4 = int(liste_affichage[15])
        question5 = int(liste_affichage[16])
        question6 = int(liste_affichage[17])
        question7 = int(liste_affichage[18])
        question8 = int(liste_affichage[19])
        question9 = int(liste_affichage[20])
        question10 = int(liste_affichage[21])
        
    if profil_r2 in ligne:
        ligne = ligne.rstrip()
        liste_affichage = ligne.split(',')
        question1_ = int(liste_affichage[12])
        question2_ = int(liste_affichage[13])
        question3_ = int(liste_affichage[14])
        question4_ = int(liste_affichage[15])
        question5_ = int(liste_affichage[16])
        question6_ = int(liste_affichage[17])
        question7_ = int(liste_affichage[18])
        question8_ = int(liste_affichage[19])
        question9_ = int(liste_affichage[20])
        question10_ = int(liste_affichage[21])

affichage.close()

distance_totale = 0

distance1 = abs(question1-question1_)
distance2 = abs(question2-question2_)
distance3 = abs(question3-question3_)
distance4 = abs(question4-question4_)
distance5 = abs(question5-question5_)
distance6 = abs(question6-question6_)
distance7 = abs(question7-question7_)
distance8 = abs(question8-question8_)
distance9 = abs(question9-question9_)
distance10 = abs(question10-question10_)
distance_totale = distance1+distance2+distance3+distance4+distance5+distance6+distance7+distance8+distance9+distance10
distance_cumulée = distance_cumulée + distance_totale

print('La distance entre toutes vos questions cumulées est de : {}\nDistance cumulée : {}'.format(distance_totale, distance_cumulée))
# Out:
# La distance entre toutes vos questions cumulées est de : 14
# Distance cumulée : 57

# %%
#Résultats
print('{} et {} sont à une distance de : {}'.format(profil_r, profil_r2, distance_cumulée))
# Out:
# lolodu13 et constdu97 sont à une distance de : 57
