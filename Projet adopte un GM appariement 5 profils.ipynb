# %%
nom_fichier = "C:\\Users\\Lorenzo\\01Informatique\\01Informatique upmc\\Exercices\Profil Database"

profil_r=input('Personne 1 : ')

print('Commençons l\'étude de compatibilité')
# Out:
# Personne 1 : lolodu13
# Commençons l'étude de compatibilité

# %%
#Le plus compatible
distance_cumulée = 0
contenu =''
liste_distance = []

import datetime
today=datetime.date.today()
liste_today=str(today).split("-")
liste_today.reverse()
liste_today

valeur = 1

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r not in ligne:
        contenu += ligne
    else:
        ligne = ligne.rstrip()
        liste_compare = ligne.split(',')
        genre = liste_compare[2]
        genre_r = liste_compare[7]
affichage.close
liste_ligne = contenu.split('\n')
for elem in liste_ligne:
    liste_profil = elem.split(',')
    genre_c = liste_profil[2]
    genre_c_r = liste_profil[7]
    if genre_r != genre_c:
        print('{} ne recherche pas le genre de {}'.format(profil_r, liste_profil[0]))
    elif genre_c_r != genre:
        print('{} ne recherche pas le genre de {}'.format(liste_profil[0], profil_r))
    else:
        affichage_naissance = liste_compare[1]
        date_naissance = affichage_naissance.split('/')
        jour=int(date_naissance[0])
        mois=int(date_naissance[1])
        annee=int(date_naissance[2])
        affichage_naissance2 = liste_profil[1]
        date_naissance2 = affichage_naissance2.split('/')
        jour2=int(date_naissance2[0])
        mois2=int(date_naissance2[1])
        annee2=int(date_naissance2[2])
        chemin_de_vie=jour+mois+annee
        chemin_de_vie2=jour2+mois2+annee2
        while chemin_de_vie > 9:
            chemin_de_vie = sum(map(int,str(chemin_de_vie)))
        while chemin_de_vie2 > 9:
            chemin_de_vie2 = sum(map(int,str(chemin_de_vie2)))
            
        distance_chemin = abs(chemin_de_vie-chemin_de_vie2)
        distance_cumulée = distance_cumulée + distance_chemin
        
        
        ASTRO = [[1 for j in range(1,14)] for i in range(1,14)]
 
        ASTRO[1][1]=50
        ASTRO[1][2]=70
        ASTRO[1][3]=50
        ASTRO[1][4]=50
        ASTRO[1][5]=60
        ASTRO[1][6]=50
        ASTRO[1][7]=70
        ASTRO[1][8]=60
        ASTRO[1][9]=70
        ASTRO[1][10]=45
        ASTRO[1][11]=90
        ASTRO[1][12]=45

        ASTRO[2][1]=85
        ASTRO[2][2]=90
        ASTRO[2][3]=70
        ASTRO[2][4]=80
        ASTRO[2][5]=55
        ASTRO[2][6]=80
        ASTRO[2][7]=70
        ASTRO[2][8]=90
        ASTRO[2][9]=80
        ASTRO[2][10]=80
        ASTRO[2][11]=60
        ASTRO[2][12]=90


        ASTRO[3][1]=50
        ASTRO[3][2]=60
        ASTRO[3][3]=75
        ASTRO[3][4]=60
        ASTRO[3][5]=50
        ASTRO[3][6]=60
        ASTRO[3][7]=70
        ASTRO[3][8]=60
        ASTRO[3][9]=70
        ASTRO[3][10]=90
        ASTRO[3][11]=90
        ASTRO[3][12]=40

        ASTRO[4][1]=50
        ASTRO[4][2]=95
        ASTRO[4][3]=65
        ASTRO[4][4]=55
        ASTRO[4][5]=95
        ASTRO[4][6]=90
        ASTRO[4][7]=75
        ASTRO[4][8]=80
        ASTRO[4][9]=55
        ASTRO[4][10]=55
        ASTRO[4][11]=70
        ASTRO[4][12]=70

        ASTRO[5][1]=50
        ASTRO[5][2]=55
        ASTRO[5][3]=45
        ASTRO[5][4]=95
        ASTRO[5][5]=45
        ASTRO[5][6]=70
        ASTRO[5][7]=70
        ASTRO[5][8]=75
        ASTRO[5][9]=90
        ASTRO[5][10]=80
        ASTRO[5][11]=70
        ASTRO[5][12]=45

        ASTRO[6][1]=40
        ASTRO[6][2]=55
        ASTRO[6][3]=55
        ASTRO[6][4]=90
        ASTRO[6][5]=75
        ASTRO[6][6]=60
        ASTRO[6][7]=60
        ASTRO[6][8]=80
        ASTRO[6][9]=80
        ASTRO[6][10]=60
        ASTRO[6][11]=40
        ASTRO[6][12]=55

        ASTRO[7][1]=60
        ASTRO[7][2]=55
        ASTRO[7][3]=65
        ASTRO[7][4]=75
        ASTRO[7][5]=90
        ASTRO[7][6]=60
        ASTRO[7][7]=70
        ASTRO[7][8]=65
        ASTRO[7][9]=90
        ASTRO[7][10]=50
        ASTRO[7][11]=90
        ASTRO[7][12]=55

        ASTRO[8][1]=55
        ASTRO[8][2]=85
        ASTRO[8][3]=60
        ASTRO[8][4]=70
        ASTRO[8][5]=90
        ASTRO[8][6]=70
        ASTRO[8][7]=55
        ASTRO[8][8]=40
        ASTRO[8][9]=95
        ASTRO[8][10]=55
        ASTRO[8][11]=50
        ASTRO[8][12]=90

        ASTRO[9][1]=60
        ASTRO[9][2]=50
        ASTRO[9][3]=70
        ASTRO[9][4]=60
        ASTRO[9][5]=90
        ASTRO[9][6]=55
        ASTRO[9][7]=85
        ASTRO[9][8]=95
        ASTRO[9][9]=90
        ASTRO[9][10]=65
        ASTRO[9][11]=90
        ASTRO[9][12]=90

        ASTRO[10][1]=60
        ASTRO[10][2]=95
        ASTRO[10][3]=70
        ASTRO[10][4]=65
        ASTRO[10][5]=90
        ASTRO[10][6]=50
        ASTRO[10][7]=45
        ASTRO[10][8]=65
        ASTRO[10][9]=40
        ASTRO[10][10]=85
        ASTRO[10][11]=80
        ASTRO[10][12]=90

        ASTRO[11][1]=70
        ASTRO[11][2]=55
        ASTRO[11][3]=80
        ASTRO[11][4]=60
        ASTRO[11][5]=80
        ASTRO[11][6]=40
        ASTRO[11][7]=90
        ASTRO[11][8]=50
        ASTRO[11][9]=75
        ASTRO[11][10]=70
        ASTRO[11][11]=75
        ASTRO[11][12]=70

        ASTRO[12][1]=45
        ASTRO[12][2]=90
        ASTRO[12][3]=40
        ASTRO[12][4]=70
        ASTRO[12][5]=50
        ASTRO[12][6]=65
        ASTRO[12][7]=70
        ASTRO[12][8]=65
        ASTRO[12][9]=80
        ASTRO[12][10]=70
        ASTRO[12][11]=45
        ASTRO[12][12]=75




        signe_compare = int(liste_compare[3])
        genre_compare = int(liste_compare[2])
        signe_compare2 = int(liste_profil[3])
        genre_compare2 = int(liste_profil[2])
        if genre_compare==1:
            distance_astro = 100-(ASTRO[signe_compare2][signe_compare])
    
        else:
            distance_astro = 100-(ASTRO[signe_compare][signe_compare2])
        distance_cumulée = distance_cumulée + distance_astro
        
        
        age_recherché = {'Entre 18 et 22ans exclu' : 1, 'Entre 22 et 26ans exclu' : 2, 'Entre 26 et 30ans exclu' : 3, 'Entre 30 et 34ans exclu' : 4, 'Entre 34 et 38ans exclu' : 5, '38 ans ou plus' : 6, 'Peu importe..' : 7}

        
        
        affichage_age = liste_compare[1]
        affichage_age_r = int(liste_compare[8])
        age_liste=affichage_age.split("/")
        age=int(liste_today[2])-int(age_liste[2])

        if (int(liste_today[1])-int(age_liste[1]))<0:
            age=age-1

        if (int(liste_today[1])-int(age_liste[1]))==0:
            if (int(liste_today[0])-int(age_liste[0]))<0:
                age=age-1

    
        affichage_age2 = liste_profil[1]
        affichage_age_r2 = int(liste_profil[8])
        age_liste2=affichage_age.split("/")
        age2=int(liste_today[2])-int(age_liste2[2])

        if (int(liste_today[1])-int(age_liste2[1]))<0:
            age2=age-1

        if (int(liste_today[1])-int(age_liste2[1]))==0:
            if (int(liste_today[0])-int(age_liste2[0]))<0:
                age2=age-1

        distance_age = []

        if affichage_age_r2 == 1:
            liste_age = [18, 19, 20, 21]
            for elem1 in liste_age:
                distance_age.append(abs(age-elem1))
            distance_cumulée = distance_cumulée + distance_age[1] #distance moyenne ne sachant pas rééllement l'âge en question
            
        if affichage_age_r2 == 2:
            liste_age = [22, 23, 24, 25]
            for elem2 in liste_age:
                distance_age.append(abs(age-elem2))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 3:
            liste_age = [26, 27, 28, 29]
            for elem3 in liste_age:
                distance_age.append(abs(age-elem3))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 4:
            liste_age = [30, 31, 32, 33]
            for elem4 in liste_age:
                distance_age.append(abs(age-elem4))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 5:
            liste_age = [34, 35, 36, 37]
            for elem5 in liste_age:
                distance_age.append(abs(age-elem5))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 6:
            doyen = 38
            distance_age2 = (abs(age-doyen))
            distance_cumulée = distance_cumulée + distance_age2
            
        if affichage_age_r2 == 7:
            print('On ne peut pas évaluer la distance pour l\'âge')

        #comparaison inverse

        if affichage_age_r == 1:
            liste_age = [18, 19, 20, 21]
            for elem1_ in liste_age:
                distance_age.append(abs(age2-elem1_))
            distance_cumulée = distance_cumulée + distance_age[1]
        
        if affichage_age_r == 2:
            liste_age = [22, 23, 24, 25]
            for elem2_ in liste_age:
                distance_age.append(abs(age2-elem2_))
            distance_cumulée = distance_cumulée + distance_age[1]

        if affichage_age_r == 3:
            liste_age = [26, 27, 28, 29]
            for elem3_ in liste_age:
                distance_age.append(abs(age2-elem3_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 4:
            liste_age = [30, 31, 32, 33]
            for elem4_ in liste_age:
                distance_age.append(abs(age2-elem4_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 5:
            liste_age = [34, 35, 36, 37]
            for elem5_ in liste_age:
                distance_age.append(abs(age2-elem5_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 6:
            doyen_ = 38
            distance_age1 = (abs(age-doyen_))
            distance_cumulée = distance_cumulée + distance_age1
            
        if affichage_age_r == 7:
            print('On ne peut pas évaluer la distance pour l\'âge')
        
        
        cheveux = int(liste_compare[5])
        cheveux_r = int(liste_compare[10])
        cheveux2 = int(liste_profil[5])
        cheveux_r2 = int(liste_profil[10])

        distance = cheveux_r-cheveux2
        distance2 = cheveux_r2-cheveux
        distance_cheveux = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_cheveux
        
        yeux = int(liste_compare[6])
        yeux_r = int(liste_compare[11])
        yeux2 = int(liste_profil[6])
        yeux_r2 = int(liste_profil[11])

        distance = yeux_r-yeux2
        distance2 = yeux_r2-yeux
        distance_yeux = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_yeux
        
        taille = int(liste_compare[4])
        taille_r = int(liste_compare[9])
        taille2 = int(liste_profil[4])
        taille_r2 = int(liste_profil[9])

        distance = taille_r-taille2
        distance2 = taille_r2-taille
        distance_taille = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_taille
        
        question1 = int(liste_compare[12])
        question2 = int(liste_compare[13])
        question3 = int(liste_compare[14])
        question4 = int(liste_compare[15])
        question5 = int(liste_compare[16])
        question6 = int(liste_compare[17])
        question7 = int(liste_compare[18])
        question8 = int(liste_compare[19])
        question9 = int(liste_compare[20])
        question10 = int(liste_compare[21])
        
        question1_ = int(liste_profil[12])
        question2_ = int(liste_profil[13])
        question3_ = int(liste_profil[14])
        question4_ = int(liste_profil[15])
        question5_ = int(liste_profil[16])
        question6_ = int(liste_profil[17])
        question7_ = int(liste_profil[18])
        question8_ = int(liste_profil[19])
        question9_ = int(liste_profil[20])
        question10_ = int(liste_profil[21])
        
        distance_totale_questions = 0

        distance1 = abs(question1-question1_)
        distance2 = abs(question2-question2_)
        distance3 = abs(question3-question3_)
        distance4 = abs(question4-question4_)
        distance5 = abs(question5-question5_)
        distance6 = abs(question6-question6_)
        distance7 = abs(question7-question7_)
        distance8 = abs(question8-question8_)
        distance9 = abs(question9-question9_)
        distance10 = abs(question10-question10_)
        distance_totale_questions = distance1+distance2+distance3+distance4+distance5+distance6+distance7+distance8+distance9+distance10
        distance_cumulée = distance_cumulée + distance_totale_questions
        
        liste_distance.append(distance_cumulée)
        
profil_compatible = []
distance_min = min(liste_distance)
index_ligne = int(liste_distance.index(min(liste_distance)))
profil_compatible = liste_ligne[index_ligne]
liste_meilleur_profil = profil_compatible.split(',')
print('Le profil le plus compatible est {} avec {} de distance'.format(liste_meilleur_profil[0], distance_min))
# Out:
# lolodu13 ne recherche pas le genre de titi
# lolodu13 ne recherche pas le genre de ouigo
# lolodu13 ne recherche pas le genre de pasmoi
# Le profil le plus compatible est constdu97 avec 57 de distance

# %%
#Essai pour trouver les 5 profils les plus compatibles
profil_compatible = []
distance_cumulée = 0
contenu =''
liste_distance = []
meilleurs_profils = []
n = 0
distance_liste_vrai = []
pascompatible = []

import datetime
today=datetime.date.today()
liste_today=str(today).split("-")
liste_today.reverse()
liste_today

valeur = 1

affichage = open(nom_fichier,"r", encoding = 'utf-8') 
for ligne in affichage: 
    if profil_r not in ligne:
        contenu += ligne
    else:
        ligne = ligne.rstrip()
        liste_compare = ligne.split(',')
        genre = liste_compare[2]
        genre_r = liste_compare[7]
affichage.close
liste_ligne = contenu.split('\n')
for element in liste_ligne:
    liste_profil = element.split(',')
    genre_c = liste_profil[2]
    genre_c_r = liste_profil[7]
    if genre_r != genre_c:
        pascompatible.append(liste_ligne[element])
        print('{} ne recherche pas le genre de {}'.format(profil_r, liste_profil[0]))
    elif genre_c_r != genre:
        pascompatible.append(liste_ligne[element])
        print('{} ne recherche pas le genre de {}'.format(liste_profil[0], profil_r))
    else:
            
        affichage_naissance = liste_compare[1]
        date_naissance = affichage_naissance.split('/')
        jour=int(date_naissance[0])
        mois=int(date_naissance[1])
        annee=int(date_naissance[2])
        affichage_naissance2 = liste_profil[1]
        date_naissance2 = affichage_naissance2.split('/')
        jour2=int(date_naissance2[0])
        mois2=int(date_naissance2[1])
        annee2=int(date_naissance2[2])
        chemin_de_vie=jour+mois+annee
        chemin_de_vie2=jour2+mois2+annee2
        while chemin_de_vie > 9:
            chemin_de_vie = sum(map(int,str(chemin_de_vie)))
        while chemin_de_vie2 > 9:
            chemin_de_vie2 = sum(map(int,str(chemin_de_vie2)))
            
        distance_chemin = abs(chemin_de_vie-chemin_de_vie2)
        distance_cumulée = distance_cumulée + distance_chemin
        
        
        ASTRO = [[1 for j in range(1,14)] for i in range(1,14)]
 
        ASTRO[1][1]=50
        ASTRO[1][2]=70
        ASTRO[1][3]=50
        ASTRO[1][4]=50
        ASTRO[1][5]=60
        ASTRO[1][6]=50
        ASTRO[1][7]=70
        ASTRO[1][8]=60
        ASTRO[1][9]=70
        ASTRO[1][10]=45
        ASTRO[1][11]=90
        ASTRO[1][12]=45

        ASTRO[2][1]=85
        ASTRO[2][2]=90
        ASTRO[2][3]=70
        ASTRO[2][4]=80
        ASTRO[2][5]=55
        ASTRO[2][6]=80
        ASTRO[2][7]=70
        ASTRO[2][8]=90
        ASTRO[2][9]=80
        ASTRO[2][10]=80
        ASTRO[2][11]=60
        ASTRO[2][12]=90


        ASTRO[3][1]=50
        ASTRO[3][2]=60
        ASTRO[3][3]=75
        ASTRO[3][4]=60
        ASTRO[3][5]=50
        ASTRO[3][6]=60
        ASTRO[3][7]=70
        ASTRO[3][8]=60
        ASTRO[3][9]=70
        ASTRO[3][10]=90
        ASTRO[3][11]=90
        ASTRO[3][12]=40

        ASTRO[4][1]=50
        ASTRO[4][2]=95
        ASTRO[4][3]=65
        ASTRO[4][4]=55
        ASTRO[4][5]=95
        ASTRO[4][6]=90
        ASTRO[4][7]=75
        ASTRO[4][8]=80
        ASTRO[4][9]=55
        ASTRO[4][10]=55
        ASTRO[4][11]=70
        ASTRO[4][12]=70

        ASTRO[5][1]=50
        ASTRO[5][2]=55
        ASTRO[5][3]=45
        ASTRO[5][4]=95
        ASTRO[5][5]=45
        ASTRO[5][6]=70
        ASTRO[5][7]=70
        ASTRO[5][8]=75
        ASTRO[5][9]=90
        ASTRO[5][10]=80
        ASTRO[5][11]=70
        ASTRO[5][12]=45

        ASTRO[6][1]=40
        ASTRO[6][2]=55
        ASTRO[6][3]=55
        ASTRO[6][4]=90
        ASTRO[6][5]=75
        ASTRO[6][6]=60
        ASTRO[6][7]=60
        ASTRO[6][8]=80
        ASTRO[6][9]=80
        ASTRO[6][10]=60
        ASTRO[6][11]=40
        ASTRO[6][12]=55

        ASTRO[7][1]=60
        ASTRO[7][2]=55
        ASTRO[7][3]=65
        ASTRO[7][4]=75
        ASTRO[7][5]=90
        ASTRO[7][6]=60
        ASTRO[7][7]=70
        ASTRO[7][8]=65
        ASTRO[7][9]=90
        ASTRO[7][10]=50
        ASTRO[7][11]=90
        ASTRO[7][12]=55

        ASTRO[8][1]=55
        ASTRO[8][2]=85
        ASTRO[8][3]=60
        ASTRO[8][4]=70
        ASTRO[8][5]=90
        ASTRO[8][6]=70
        ASTRO[8][7]=55
        ASTRO[8][8]=40
        ASTRO[8][9]=95
        ASTRO[8][10]=55
        ASTRO[8][11]=50
        ASTRO[8][12]=90

        ASTRO[9][1]=60
        ASTRO[9][2]=50
        ASTRO[9][3]=70
        ASTRO[9][4]=60
        ASTRO[9][5]=90
        ASTRO[9][6]=55
        ASTRO[9][7]=85
        ASTRO[9][8]=95
        ASTRO[9][9]=90
        ASTRO[9][10]=65
        ASTRO[9][11]=90
        ASTRO[9][12]=90

        ASTRO[10][1]=60
        ASTRO[10][2]=95
        ASTRO[10][3]=70
        ASTRO[10][4]=65
        ASTRO[10][5]=90
        ASTRO[10][6]=50
        ASTRO[10][7]=45
        ASTRO[10][8]=65
        ASTRO[10][9]=40
        ASTRO[10][10]=85
        ASTRO[10][11]=80
        ASTRO[10][12]=90

        ASTRO[11][1]=70
        ASTRO[11][2]=55
        ASTRO[11][3]=80
        ASTRO[11][4]=60
        ASTRO[11][5]=80
        ASTRO[11][6]=40
        ASTRO[11][7]=90
        ASTRO[11][8]=50
        ASTRO[11][9]=75
        ASTRO[11][10]=70
        ASTRO[11][11]=75
        ASTRO[11][12]=70

        ASTRO[12][1]=45
        ASTRO[12][2]=90
        ASTRO[12][3]=40
        ASTRO[12][4]=70
        ASTRO[12][5]=50
        ASTRO[12][6]=65
        ASTRO[12][7]=70
        ASTRO[12][8]=65
        ASTRO[12][9]=80
        ASTRO[12][10]=70
        ASTRO[12][11]=45
        ASTRO[12][12]=75




        signe_compare = int(liste_compare[3])
        genre_compare = int(liste_compare[2])
        signe_compare2 = int(liste_profil[3])
        genre_compare2 = int(liste_profil[2])
        if genre_compare==1:
            distance_astro = 100-(ASTRO[signe_compare2][signe_compare])
    
        else:
            distance_astro = 100-(ASTRO[signe_compare][signe_compare2])
        distance_cumulée = distance_cumulée + distance_astro
        
        
        age_recherché = {'Entre 18 et 22ans exclu' : 1, 'Entre 22 et 26ans exclu' : 2, 'Entre 26 et 30ans exclu' : 3, 'Entre 30 et 34ans exclu' : 4, 'Entre 34 et 38ans exclu' : 5, '38 ans ou plus' : 6, 'Peu importe..' : 7}

        
        
        affichage_age = liste_compare[1]
        affichage_age_r = int(liste_compare[8])
        age_liste=affichage_age.split("/")
        age=int(liste_today[2])-int(age_liste[2])

        if (int(liste_today[1])-int(age_liste[1]))<0:
            age=age-1

        if (int(liste_today[1])-int(age_liste[1]))==0:
            if (int(liste_today[0])-int(age_liste[0]))<0:
                age=age-1

    
        affichage_age2 = liste_profil[1]
        affichage_age_r2 = int(liste_profil[8])
        age_liste2=affichage_age.split("/")
        age2=int(liste_today[2])-int(age_liste2[2])

        if (int(liste_today[1])-int(age_liste2[1]))<0:
            age2=age-1

        if (int(liste_today[1])-int(age_liste2[1]))==0:
            if (int(liste_today[0])-int(age_liste2[0]))<0:
                age2=age-1

        
        distance_age = []

        if affichage_age_r2 == 1:
            liste_age = [18, 19, 20, 21]
            for elem1 in liste_age:
                distance_age.append(abs(age-elem1))
            distance_cumulée = distance_cumulée + distance_age[1] #distance moyenne ne sachant pas rééllement l'âge en question
            
        if affichage_age_r2 == 2:
            liste_age = [22, 23, 24, 25]
            for elem2 in liste_age:
                distance_age.append(abs(age-elem2))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 3:
            liste_age = [26, 27, 28, 29]
            for elem3 in liste_age:
                distance_age.append(abs(age-elem3))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 4:
            liste_age = [30, 31, 32, 33]
            for elem4 in liste_age:
                distance_age.append(abs(age-elem4))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 5:
            liste_age = [34, 35, 36, 37]
            for elem5 in liste_age:
                distance_age.append(abs(age-elem5))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r2 == 6:
            doyen = 38
            distance_age2 = (abs(age-doyen))
            distance_cumulée = distance_cumulée + distance_age2
            
        if affichage_age_r2 == 7:
            print('On ne peut pas évaluer la distance pour l\'âge')

        #comparaison inverse

        if affichage_age_r == 1:
            liste_age = [18, 19, 20, 21]
            for elem1_ in liste_age:
                distance_age.append(abs(age2-elem1_))
            distance_cumulée = distance_cumulée + distance_age[1]
        
        if affichage_age_r == 2:
            liste_age = [22, 23, 24, 25]
            for elem2_ in liste_age:
                distance_age.append(abs(age2-elem2_))
            distance_cumulée = distance_cumulée + distance_age[1]

        if affichage_age_r == 3:
            liste_age = [26, 27, 28, 29]
            for elem3_ in liste_age:
                distance_age.append(abs(age2-elem3_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 4:
            liste_age = [30, 31, 32, 33]
            for elem4_ in liste_age:
                distance_age.append(abs(age2-elem4_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 5:
            liste_age = [34, 35, 36, 37]
            for elem5_ in liste_age:
                distance_age.append(abs(age2-elem5_))
            distance_cumulée = distance_cumulée + distance_age[1]
            
        if affichage_age_r == 6:
            doyen_ = 38
            distance_age1 = (abs(age-doyen_))
            distance_cumulée = distance_cumulée + distance_age1
            
        if affichage_age_r == 7:
            print('On ne peut pas évaluer la distance pour l\'âge')
        
        
        cheveux = int(liste_compare[5])
        cheveux_r = int(liste_compare[10])
        cheveux2 = int(liste_profil[5])
        cheveux_r2 = int(liste_profil[10])

        distance = cheveux_r-cheveux2
        distance2 = cheveux_r2-cheveux
        distance_cheveux = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_cheveux
        
        yeux = int(liste_compare[6])
        yeux_r = int(liste_compare[11])
        yeux2 = int(liste_profil[6])
        yeux_r2 = int(liste_profil[11])

        distance = yeux_r-yeux2
        distance2 = yeux_r2-yeux
        distance_yeux = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_yeux
        
        taille = int(liste_compare[4])
        taille_r = int(liste_compare[9])
        taille2 = int(liste_profil[4])
        taille_r2 = int(liste_profil[9])

        distance = taille_r-taille2
        distance2 = taille_r2-taille
        distance_taille = abs(distance + distance2)
        distance_cumulée = distance_cumulée + distance_taille
        
        question1 = int(liste_compare[12])
        question2 = int(liste_compare[13])
        question3 = int(liste_compare[14])
        question4 = int(liste_compare[15])
        question5 = int(liste_compare[16])
        question6 = int(liste_compare[17])
        question7 = int(liste_compare[18])
        question8 = int(liste_compare[19])
        question9 = int(liste_compare[20])
        question10 = int(liste_compare[21])
        
        question1_ = int(liste_profil[12])
        question2_ = int(liste_profil[13])
        question3_ = int(liste_profil[14])
        question4_ = int(liste_profil[15])
        question5_ = int(liste_profil[16])
        question6_ = int(liste_profil[17])
        question7_ = int(liste_profil[18])
        question8_ = int(liste_profil[19])
        question9_ = int(liste_profil[20])
        question10_ = int(liste_profil[21])
        
        distance_totale_questions = 0

        distance1 = abs(question1-question1_)
        distance2 = abs(question2-question2_)
        distance3 = abs(question3-question3_)
        distance4 = abs(question4-question4_)
        distance5 = abs(question5-question5_)
        distance6 = abs(question6-question6_)
        distance7 = abs(question7-question7_)
        distance8 = abs(question8-question8_)
        distance9 = abs(question9-question9_)
        distance10 = abs(question10-question10_)
        distance_totale_questions = distance1+distance2+distance3+distance4+distance5+distance6+distance7+distance8+distance9+distance10
        distance_cumulée = distance_cumulée + distance_totale_questions
        
        liste_distance.append(distance_cumulée)
        
for i in range (0, len(pascompatible)):
    if pascompatible[i] in liste_ligne:
        liste_ligne.pop(i)
print(liste_ligne)
distance_profil1 = liste_distance[0]
distance_profil2 = liste_distance[1]-distance_profil1
distance_profil3 = liste_distance[2]-liste_distance[1]
distance_profil4 = liste_distance[3]-liste_distance[2]
distance_profil5 = liste_distance[4]-liste_distance[3]
distance_liste_vrai.append(distance_profil1)
distance_liste_vrai.append(distance_profil2)
distance_liste_vrai.append(distance_profil3)
distance_liste_vrai.append(distance_profil4)
distance_liste_vrai.append(distance_profil5)
print(distance_liste_vrai)
        
while n<5:
    distance_min = min(distance_liste_vrai)
    index_ligne = int(distance_liste_vrai.index(min(distance_liste_vrai)))
    profil_compatible = liste_ligne[index_ligne+n]
    liste_meilleur_profil = profil_compatible.split(',')
    meilleurs_profils.append(liste_meilleur_profil[0])
    distance_liste_vrai.pop(index_ligne)
    print(distance_liste_vrai)
    n = n+1
print(meilleurs_profils)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d305d5870858> in <module>()
#      33     genre_c_r = liste_profil[7]
#      34     if genre_r != genre_c:
# ---> 35         pascompatible.append(liste_ligne[element])
#      36         print('{} ne recherche pas le genre de {}'.format(profil_r, liste_profil[0]))
#      37     elif genre_c_r != genre:
#
# TypeError: list indices must be integers or slices, not str

# %%
while n<5:
            distance_min = min(liste_distance)
            index_ligne = int(liste_distance.index(min(liste_distance)))
            profil_compatible = liste_ligne[index_ligne]
            liste_meilleur_profil = profil_compatible.split(',')
            meilleurs_profils.append(liste_meilleur_profil[0])
            liste_distance.pop(index_ligne)
            print(liste_distance)
            n = n+1
print(meilleurs_profils)
#print('Le profil le plus compatible est {} avec {} de distance'.format(liste_meilleur_profil[0], distance_min))
#print(liste_distance)
            
        #print(age, age2)
        #changer les phrases

        
        
#print(liste_profil)
#print(contenu)
